# %% [markdown]
# # 깊은 다층 퍼셉트론으로 MNIST 손글씨 인식
# - 데이터 전처리, 모델 정의, 학습, 평가, 시각화 진행

# %% [markdown]
# ## 라이브러리 불러오기

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
ds.mnist
# Out:
# <module 'keras.datasets.mnist' from 'c:\\Users\\user\\anaconda3\\envs\\cv\\Lib\\site-packages\\keras\\datasets\\mnist\\__init__.py'>

# %% [markdown]
# ## 데이터 전처리
#
# - MNIST 데이터셋 불러오기 및 전처리
# - 데이터는 28x28 흑백 이미지를 1차원 벡터(784차원)로 변환
# - 픽셀 값을 [0, 1] 범위로 정규화
# - 레이블을 원-핫 인코딩으로 변환

# %%
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# 데이터 정규화 및 1차원 벡터로 변환
x_train = x_train.reshape(60000, 784).astype(np.float32) / 255.0
x_test = x_test.reshape(10000, 784).astype(np.float32) / 255.0

# 레이블을 원-핫 인코딩으로 변환
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
dmlp = Sequential()
dmlp.add(Input(shape=(784,)))
dmlp.add(Dense(units=1024, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dropout(0.4))
dmlp.add(Dense(units=10, activation='softmax'))

# %% [markdown]
# ## 모델 컴파일 및 학습
#
# - 손실 함수: categorical_crossentropy (다중 클래스 분류)
# - 옵티마이저: Adam
# - 평가 지표: accuracy
# - 배치 크기 : 128, 에포크 : 50 으로 학습 진행

# %%
dmlp.compile(loss='categorical_crossentropy', optimizer=Adam(learning_rate=0.01), metrics=['accuracy'])
hist = dmlp.fit(x_train, y_train, batch_size=128, epochs=30, validation_data=(x_test, y_test), verbose=2)
# Out:
# Epoch 1/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8371 - loss: 0.6200 - val_accuracy: 0.9337 - val_loss: 0.2745
# Epoch 2/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8371 - loss: 0.6200 - val_accuracy: 0.9337 - val_loss: 0.2745
# Epoch 2/30
# 469/469 - 34s - 73ms/step - accuracy: 0.8735 - loss: 0.5467 - val_accuracy: 0.9312 - val_loss: 0.3165
# Epoch 3/30
# 469/469 - 34s - 73ms/step - accuracy: 0.8735 - loss: 0.5467 - val_accuracy: 0.9312 - val_loss: 0.3165
# Epoch 3/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8626 - loss: 0.5982 - val_accuracy: 0.9325 - val_loss: 0.3342
# Epoch 4/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8626 - loss: 0.5982 - val_accuracy: 0.9325 - val_loss: 0.3342
# Epoch 4/30
# 469/469 - 36s - 76ms/step - accuracy: 0.8636 - loss: 0.5939 - val_accuracy: 0.9353 - val_loss: 0.3159
# Epoch 5/30
# 469/469 - 36s - 76ms/step - accuracy: 0.8636 - loss: 0.5939 - val_accuracy: 0.9353 - val_loss: 0.3159
# Epoch 5/30
# 469/469 - 23s - 50ms/step - accuracy: 0.8668 - loss: 0.5773 - val_accuracy: 0.9342 - val_loss: 0.2967
# Epoch 6/30
# 469/469 - 23s - 50ms/step - accuracy: 0.8668 - loss: 0.5773 - val_accuracy: 0.9342 - val_loss: 0.2967
# Epoch 6/30
# 469/469 - 23s - 49ms/step - accuracy: 0.8694 - loss: 0.5788 - val_accuracy: 0.9363 - val_loss: 0.3288
# Epoch 7/30
# 469/469 - 23s - 49ms/step - accuracy: 0.8694 - loss: 0.5788 - val_accuracy: 0.9363 - val_loss: 0.3288
# Epoch 7/30
# 469/469 - 41s - 87ms/step - accuracy: 0.8674 - loss: 0.6017 - val_accuracy: 0.9252 - val_loss: 0.3424
# Epoch 8/30
# 469/469 - 41s - 87ms/step - accuracy: 0.8674 - loss: 0.6017 - val_accuracy: 0.9252 - val_loss: 0.3424
# Epoch 8/30
# 469/469 - 42s - 89ms/step - accuracy: 0.8679 - loss: 0.5919 - val_accuracy: 0.9368 - val_loss: 0.2921
# Epoch 9/30
# 469/469 - 45s - 97ms/step - accuracy: 0.8622 - loss: 0.5919 - val_accuracy: 0.9268 - val_loss: 0.4076
# Epoch 21/30
# 469/469 - 42s - 90ms/step - accuracy: 0.8673 - loss: 0.5773 - val_accuracy: 0.9315 - val_loss: 0.3723
# Epoch 22/30
# 469/469 - 42s - 90ms/step - accuracy: 0.8673 - loss: 0.5773 - val_accuracy: 0.9315 - val_loss: 0.3723
# Epoch 22/30
# 469/469 - 34s - 73ms/step - accuracy: 0.8681 - loss: 0.5714 - val_accuracy: 0.9391 - val_loss: 0.3589
# Epoch 23/30
# 469/469 - 34s - 73ms/step - accuracy: 0.8681 - loss: 0.5714 - val_accuracy: 0.9391 - val_loss: 0.3589
# Epoch 23/30
# 469/469 - 35s - 75ms/step - accuracy: 0.8623 - loss: 0.6022 - val_accuracy: 0.9242 - val_loss: 0.4052
# Epoch 24/30
# 469/469 - 35s - 75ms/step - accuracy: 0.8623 - loss: 0.6022 - val_accuracy: 0.9242 - val_loss: 0.4052
# Epoch 24/30
# 469/469 - 31s - 66ms/step - accuracy: 0.8579 - loss: 0.5896 - val_accuracy: 0.9135 - val_loss: 0.3759
# Epoch 25/30
# 469/469 - 31s - 66ms/step - accuracy: 0.8579 - loss: 0.5896 - val_accuracy: 0.9135 - val_loss: 0.3759
# Epoch 25/30
# 469/469 - 43s - 93ms/step - accuracy: 0.8526 - loss: 0.6002 - val_accuracy: 0.9261 - val_loss: 0.4619
# Epoch 26/30
# 469/469 - 43s - 93ms/step - accuracy: 0.8526 - loss: 0.6002 - val_accuracy: 0.9261 - val_loss: 0.4619
# Epoch 26/30
# 469/469 - 33s - 71ms/step - accuracy: 0.8544 - loss: 0.6153 - val_accuracy: 0.9279 - val_loss: 0.4197
# Epoch 27/30
# 469/469 - 33s - 71ms/step - accuracy: 0.8544 - loss: 0.6153 - val_accuracy: 0.9279 - val_loss: 0.4197
# Epoch 27/30
# 469/469 - 38s - 81ms/step - accuracy: 0.8587 - loss: 0.5823 - val_accuracy: 0.9263 - val_loss: 0.5341
# Epoch 28/30
# 469/469 - 38s - 81ms/step - accuracy: 0.8587 - loss: 0.5823 - val_accuracy: 0.9263 - val_loss: 0.5341
# Epoch 28/30
# 469/469 - 30s - 63ms/step - accuracy: 0.8568 - loss: 0.6257 - val_accuracy: 0.9272 - val_loss: 0.3714
# Epoch 29/30
# 469/469 - 30s - 63ms/step - accuracy: 0.8568 - loss: 0.6257 - val_accuracy: 0.9272 - val_loss: 0.3714
# Epoch 29/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8606 - loss: 0.5911 - val_accuracy: 0.9136 - val_loss: 0.3996
# Epoch 30/30
# 469/469 - 29s - 62ms/step - accuracy: 0.8606 - loss: 0.5911 - val_accuracy: 0.9136 - val_loss: 0.3996
# Epoch 30/30
# 469/469 - 30s - 64ms/step - accuracy: 0.8548 - loss: 0.6218 - val_accuracy: 0.9075 - val_loss: 0.4615
# 469/469 - 30s - 64ms/step - accuracy: 0.8548 - loss: 0.6218 - val_accuracy: 0.9075 - val_loss: 0.4615

# %% [markdown]
# ## 모델 평가

# %%
accuracy = dmlp.evaluate(x_test, y_test, verbose=0)[1] * 100
print(f'정확률 = {accuracy:.2f}%')
# Out:
# 정확률 = 90.75%

# %% [markdown]
# ## 모델 저장

# %%
dmlp.save('dmlp_trained.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# ## 모델 시각화

# %%
# 정확도 그래프
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Accuracy graph')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['train', 'test'])
plt.grid()
plt.show()

# 손실 그래프
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Loss graph')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'test'])
plt.grid()
plt.show()
