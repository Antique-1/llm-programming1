# %% [markdown]
# <a href="https://colab.research.google.com/github/Antique-1/llm-programming1/blob/main/11_04_1_1_%EB%9E%AD%EC%B2%B4%EC%9D%B8_%EC%B3%87%EB%B4%87_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 랭체인 챗봇 만들기
# - LangChain과 OpenAI 모델을 사용하여 기본적인 챗봇 구현
# - 챗봇이 메모리를 갖지 않는 상태 확인

# %% [markdown]
# ## 필요 라이브러리 설치

# %%
# %pip install langchain langchain-openai
# Out:
# ...
# INFO: pip is looking at multiple versions of langchain-openai to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.0/76.0 kB 4.0 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## API KEY 불러오기

# %%
from openai import OpenAI
from dotenv import load_dotenv
import os

# %%
api_key =
client = OpenAI(api_key=api_key)

# %% [markdown]
# ## 모델 선언

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(
    model="gpt-4o-mini",
    api_key=api_key
)

# %% [markdown]
# ## 첫 번째 대화

# %%
from langchain_core.messages import HumanMessage
model.invoke([HumanMessage(content="안녕? 나는 김정은이야.")])
# Out:
# AIMessage(content='안녕하세요, 김정은님! 어떻게 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 17, 'total_tokens': 32, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CY0VAWdk5HGJZ21m2loPF0F8ycYat', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--e83baefa-6bc5-4083-a3ca-da1062f2e19b-0', usage_metadata={'input_tokens': 17, 'output_tokens': 15, 'total_tokens': 32, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## 두 번째 대화

# %%
model.invoke([HumanMessage(content="내 이름이 뭐지?")])
# Out:
# AIMessage(content='죄송하지만, 당신의 이름을 알 수 있는 방법이 없습니다. 어떤 이름을 원하시나요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 13, 'total_tokens': 35, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-CY0VGm4oF26NmWy8JiGHPCFXPSAOX', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--985fa9aa-a5ed-4a10-851a-0d9af138c233-0', usage_metadata={'input_tokens': 13, 'output_tokens': 22, 'total_tokens': 35, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})
